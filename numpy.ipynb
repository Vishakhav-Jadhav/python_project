# %%
#numpy

# %%
import numpy as np
print("hello world")
# Out:
# hello world

# %%
myarr = np.array([[1,2,3]])
myarr[0]
# Out:
# array([1, 2, 3])

# %%
myarr.shape
# Out:
# (1, 3)

# %%
import numpy as np # with tuple
my_arr=np.array((12,3,5,58))
my_arr
# Out:
# array([12,  3,  5, 58])

# %%
#0-D arrays
import numpy as np
arr=np.array(34)
arr
# Out:
# array(34)

# %%
# 1-D array
import numpy as np 
arr=np.array([12,3,4])
arr
# Out:
# array([12,  3,  4])

# %%
#2-D array array that has 1d element is called 2d array
arr=np.array([[12,3,4],[34,6,7]])
arr
# Out:
# array([[12,  3,  4],
#        [34,  6,  7]])

# %%
#3d arrayy it has  2d array element called 3d array
import numpy as np
arr=np.array([[[1,3,4],[7,6,7]],[[12,5,6],[5,6,7]]])
arr
# Out:
# array([[[ 1,  3,  4],
#         [ 7,  6,  7]],
#
#        [[12,  5,  6],
#         [ 5,  6,  7]]])

# %%
import numpy as np
a=np.array(45)
b=np.array([12,34,57])
c=np.array([[13,67,88],[7,8,9]])
d=np.array([[[12,45,77],[45,89,78]],[[45,78,65],[34,98,17]]])
print(a.ndim)
print(b.ndim)
print(c.ndim)
print(d.ndim)
# Out:
# 0
# 1
# 2
# 3

# %%
import numpy as np
b=np.array([12,34,57],ndmin=5)
print(b)

print('no of dimention',b.ndim)
# Out:
# [[[[[12 34 57]]]]]
# no of dimention 5

# %%
arrr=np.arange(50)
arr
